# %% [markdown]
# #### Create the classes and functions as per following description:
# - Create a class Person :
#    - The attributes of the class are name, age, city
#    - The functions of the class are :
#        - __init__(self, name, age, city)
#        - show_details(self)
#        - update_city(self, new_city)
#
# - Create a class Employee which inherits the class Person:
#     - The attributes of the class are name , age, city, salary, position, dept
#     - The functions of the class are :
#         - __init__(self, name , age, city, salary, position, dept)
#         - show_details(self)
#         - update_salary(self, new_salary)
#         - update_dept(self, new_dept)
#         - update_position(self, new_pos)
#         - inc_salary(self)
#         - dec_salary
#
# - Make use of the super function when necessary
# - Create objects and Demonstrate working of all the functions

# %%
class Person:
    def __init__(self, name, age, city):
        self.name = name
        self.age = age
        self.city = city

    def show_details(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"City: {self.city}")

    def update_city(self, new_city):
        self.city = new_city


class Employee(Person):
    def __init__(self, name, age, city, salary, position, dept):
        super().__init__(name, age, city)
        self.salary = salary
        self.position = position
        self.dept = dept

    def show_details(self):
        super().show_details()
        print(f"Salary: {self.salary}")
        print(f"Position: {self.position}")
        print(f"Department: {self.dept}")

    def update_salary(self, new_salary):
        self.salary = new_salary

    def update_dept(self, new_dept):
        self.dept = new_dept

    def update_position(self, new_pos):
        self.position = new_pos

    def inc_salary(self, amount):
        self.salary += amount

    def dec_salary(self, amount):
        self.salary -= amount


person1 = Person("Madhavan", 30, "New York")
print("Person 1 Details:")
person1.show_details()
person1.update_city("San Francisco")
print("Updated City for Person 1:")
person1.show_details()
print("\n")

employee1 = Employee("Maddy", 25, "Los Angeles", 60000, "Developer", "Engineering")
print("Employee 1 Details:")
employee1.show_details()
employee1.update_salary(65000)
employee1.update_dept("Product Management")
employee1.update_position("Senior Developer")
print()
print("Updated Employee 1 Details:")
print()
employee1.show_details()
employee1.inc_salary(5000)
employee1.dec_salary(2000)
print("Updated Salary for Employee 1:")
print()
employee1.show_details()
# Out:
# Person 1 Details:
# Name: Madhavan
# Age: 30
# City: New York
# Updated City for Person 1:
# Name: Madhavan
# Age: 30
# City: San Francisco
#
#
# Employee 1 Details:
# Name: Maddy
# Age: 25
# City: Los Angeles
# Salary: 60000
# Position: Developer
# Department: Engineering
#
# Updated Employee 1 Details:
#
# Name: Maddy
# Age: 25
# City: Los Angeles
# Salary: 65000
# Position: Senior Developer
# Department: Product Management
# Updated Salary for Employee 1:
#
# Name: Maddy
# Age: 25
# City: Los Angeles
# Salary: 68000
# Position: Senior Developer
# Department: Product Management
